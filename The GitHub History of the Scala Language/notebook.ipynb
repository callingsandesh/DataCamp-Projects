# %% [markdown]
# ## 1. Scala's real-world project repository data
# <p>With almost 30k commits and a history spanning over ten years, Scala is a mature programming language. It is a general-purpose programming language that has recently become another prominent language for data scientists.</p>
# <p>Scala is also an open source project. Open source projects have the advantage that their entire development histories -- who made changes, what was changed, code reviews, etc. -- are publicly available. </p>
# <p>We're going to read in, clean up, and visualize the real world project repository of Scala that spans data from a version control system (Git) as well as a project hosting site (GitHub). We will find out who has had the most influence on its development and who are the experts.</p>
# <p>The dataset we will use, which has been previously mined and extracted from GitHub, is comprised of three files:</p>
# <ol>
# <li><code>pulls_2011-2013.csv</code> contains the basic information about the pull requests, and spans from the end of 2011 up to (but not including) 2014.</li>
# <li><code>pulls_2014-2018.csv</code> contains identical information, and spans from 2014 up to 2018.</li>
# <li><code>pull_files.csv</code> contains the files that were modified by each pull request.</li>
# </ol>

# %%
# Importing pandas
import pandas as pd

# Loading in the data
pulls_one = pd.read_csv("datasets/pulls_2011-2013.csv")
pulls_two = pd.read_csv("datasets/pulls_2014-2018.csv")
pull_files = pd.read_csv('datasets/pull_files.csv')

# %% [markdown]
# ## 2. Preparing and cleaning the data
# <p>First, we will need to combine the data from the two separate pull DataFrames. </p>
# <p>Next, the raw data extracted from GitHub contains dates in the ISO8601 format. However, <code>pandas</code> imports them as regular strings. To make our analysis easier, we need to convert the strings into Python's <code>DateTime</code> objects. <code>DateTime</code> objects have the important property that they can be compared and sorted.</p>
# <p>The pull request times are all in UTC (also known as Coordinated Universal Time). The commit times, however, are in the local time of the author with time zone information (number of hours difference from UTC). To make comparisons easy, we should convert all times to UTC.</p>

# %%
# Append pulls_one to pulls_two

pulls =pulls_one.append(pulls_two)

# Convert the date for the pulls object
pulls['date'] = pd.to_datetime(pulls['date'],utc=True)
print(pulls)
# Out:
#            pid                user                      date
# 0     11166973         VladimirNik 2013-12-31 23:10:55+00:00
# 1     11161892             Ichoran 2013-12-31 16:55:47+00:00
# 2     11153894             Ichoran 2013-12-31 02:41:13+00:00
# 3     11151917             rklaehn 2013-12-30 23:45:47+00:00
# 4     11131244               qerub 2013-12-29 17:21:01+00:00
# 5     11130874             Ichoran 2013-12-29 16:03:55+00:00
# 6     11129556             rklaehn 2013-12-29 10:15:46+00:00
# 7     11126653             xeno-by 2013-12-28 19:39:23+00:00
# 8     11126070  OlivierBlanvillain 2013-12-28 17:32:51+00:00
# 9     11121557             xeno-by 2013-12-27 23:50:56+00:00
# 10    11121465             xeno-by 2013-12-27 23:41:05+00:00
# 11    11121327             xeno-by 2013-12-27 23:25:52+00:00
# 12    11114584             xeno-by 2013-12-27 15:51:50+00:00
# 13    11114355             rklaehn 2013-12-27 15:37:25+00:00
# 14    11104796               paulp 2013-12-27 00:49:23+00:00
# 15    11100618             Ichoran 2013-12-26 19:08:10+00:00
# 16    11096632             xeno-by 2013-12-26 14:18:52+00:00
# 17    11079637                 non 2013-12-24 21:00:22+00:00
# 18    11065948             Ichoran 2013-12-24 01:34:09+00:00
# 19    11065140             Ichoran 2013-12-24 00:21:15+00:00
# 20    11064556             Ichoran 2013-12-23 23:37:37+00:00
# 21    11062700             Ichoran 2013-12-23 21:53:47+00:00
# 22    11046915             xuwei-k 2013-12-23 08:18:23+00:00
# 23    11042476            retronym 2013-12-22 20:12:00+00:00
# 24    11037693               paulp 2013-12-21 23:38:32+00:00
# 25    11035104  OlivierBlanvillain 2013-12-21 15:10:29+00:00
# 26    11034849                gzm0 2013-12-21 14:13:34+00:00
# 27    11015327                gzm0 2013-12-20 15:58:35+00:00
# 28    11003958                 soc 2013-12-20 08:32:38+00:00
# 29    10992566             xeno-by 2013-12-19 22:02:41+00:00
# ...        ...                 ...                       ...
# 2874  11419485           som-snytt 2014-01-10 22:31:45+00:00
# 2875  11399439             xeno-by 2014-01-10 12:59:16+00:00
# 2876  11394591            retronym 2014-01-10 09:50:33+00:00
# 2877  11394178               dotta 2014-01-10 09:33:51+00:00
# 2878  11385248             xeno-by 2014-01-10 00:36:25+00:00
# 2879  11381400            retronym 2014-01-09 22:29:48+00:00
# 85559  11245823            retronym 2014-01-06 10:30:32+00:00
# 85560  11245823            retronym 2014-01-06 10:30:32+00:00
# 85561  11245823            retronym 2014-01-06 10:30:32+00:00
# 85562  11245823            retronym 2014-01-06 10:30:32+00:00
# 85563  11245823            retronym 2014-01-06 10:30:32+00:00
# 85564  11245823            retronym 2014-01-06 10:30:32+00:00
# 85565  11245823            retronym 2014-01-06 10:30:32+00:00
# 85566  11245823            retronym 2014-01-06 10:30:32+00:00
# 85567  11245823            retronym 2014-01-06 10:30:32+00:00
# 85568  11245823            retronym 2014-01-06 10:30:32+00:00
# 85569  11245823            retronym 2014-01-06 10:30:32+00:00
# 85570  11245823            retronym 2014-01-06 10:30:32+00:00
# 85571  11245823            retronym 2014-01-06 10:30:32+00:00
# 85572  11245823            retronym 2014-01-06 10:30:32+00:00
# 85573  11245823            retronym 2014-01-06 10:30:32+00:00
# 85574  11245823            retronym 2014-01-06 10:30:32+00:00
# 85575  11245823            retronym 2014-01-06 10:30:32+00:00
# 85576  11244241              folone 2014-01-06 09:07:34+00:00
# 85577  11244241              folone 2014-01-06 09:07:34+00:00
# 85578  11244241              folone 2014-01-06 09:07:34+00:00
# 85579  11240674            clhodapp 2014-01-06 03:52:23+00:00
# 85580  11240674            clhodapp 2014-01-06 03:52:23+00:00
# 85581  11234757             xeno-by 2014-01-05 12:23:24+00:00
# 85582  11231462             rklaehn 2014-01-04 22:42:02+00:00
# 85583  11231462             rklaehn 2014-01-04 22:42:02+00:00
# 85584  11188295             rklaehn 2014-01-02 18:55:33+00:00
# 85585  11188295             rklaehn 2014-01-02 18:55:33+00:00
# 85586  11188295             rklaehn 2014-01-02 18:55:33+00:00
# 85587  11188295             rklaehn 2014-01-02 18:55:33+00:00
#
#                                                     file
# 0           src/reflect/scala/reflect/api/Printers.scala
# 1      src/reflect/scala/reflect/internal/Printers.scala
# 2                        test/files/run/reify_ann3.check
# 3      test/junit/scala/reflect/internal/PrintersTest...
# 4      src/library/scala/collection/mutable/ArrayOps....
# 5      src/library/scala/collection/immutable/Numeric...
# 6      test/junit/scala/collection/NumericRangeTest.s...
# 7      src/library/scala/collection/immutable/HashMap...
# 8      src/library/scala/collection/immutable/HashSet...
# 9                             test/files/run/t6196.scala
# 10                            test/files/run/t6200.scala
# 11                   src/library/scala/Enumeration.scala
# 12     src/library/scala/collection/immutable/StringL...
# 13           src/library/scala/util/matching/Regex.scala
# 14     src/repl/scala/tools/nsc/interpreter/JavapClas...
# 15     src/repl/scala/tools/nsc/interpreter/Naming.scala
# 16               src/library/scala/math/BigDecimal.scala
# 17                   src/library/scala/math/BigInt.scala
# 18                          test/files/jvm/bigints.scala
# 19                   test/files/run/bigDecimalTest.check
# 20                     test/files/run/is-valid-num.scala
# 21                         test/files/run/numbereq.scala
# 22            test/junit/scala/math/BigDecimalTest.scala
# 23     src/library/scala/collection/immutable/HashSet...
# 24                            test/files/run/t7326.scala
# 25      src/reflect/scala/reflect/internal/Mirrors.scala
# 26     test/junit/scala/reflect/internal/MirrorsTest....
# 27     src/library/scala/collection/convert/DecorateA...
# 28     src/library/scala/collection/convert/WrapAsJav...
# 29             src/library/scala/ref/WeakReference.scala
# ...                                                  ...
# 85558                         test/files/pos/t8062.flags
# 85559                     test/files/pos/t8062/A_1.scala
# 85560                     test/files/pos/t8062/B_2.scala
# 85561                         test/files/pos/t8111.scala
# 85562                test/files/presentation/t8085.check
# 85563                test/files/presentation/t8085.flags
# 85564           test/files/presentation/t8085/Test.scala
# 85565  test/files/presentation/t8085/src/nodescala/Fo...
# 85566  test/files/presentation/t8085/src/nodescala/No...
# 85567  test/files/presentation/t8085/src/nodescala/pa...
# 85568               test/files/presentation/t8085b.check
# 85569               test/files/presentation/t8085b.flags
# 85570          test/files/presentation/t8085b/Test.scala
# 85571  test/files/presentation/t8085b/src/p1/nodescal...
# 85572  test/files/presentation/t8085b/src/p1/nodescal...
# 85573  test/files/presentation/t8085b/src/p1/nodescal...
# 85574                    test/files/run/large_code.check
# 85575                    test/files/run/large_code.scala
# 85576  src/reflect/scala/reflect/api/StandardLiftable...
# 85577  test/files/scalacheck/quasiquotes/LiftableCase...
# 85578       test/files/scalacheck/quasiquotes/Test.scala
# 85579               src/library/scala/math/Numeric.scala
# 85580            test/junit/scala/math/NumericTest.scala
# 85581          src/reflect/scala/reflect/api/Trees.scala
# 85582  src/library/scala/collection/immutable/HashMap...
# 85583  src/library/scala/collection/immutable/HashSet...
# 85584  src/library/scala/collection/immutable/HashSet...
# 85585                        test/files/run/t6253a.scala
# 85586                        test/files/run/t6253b.scala
# 85587                        test/files/run/t6253c.scala
#
# [85588 rows x 4 columns]

# %% [markdown]
# ## 4. Is the project still actively maintained?
# <p>The activity in an open source project is not very consistent. Some projects might be active for many years after the initial release, while others can slowly taper out into oblivion. Before committing to contributing to a project, it is important to understand the state of the project. Is development going steadily, or is there a drop? Has the project been abandoned altogether?</p>
# <p>The data used in this project was collected in January of 2018. We are interested in the evolution of the number of contributions up to that date.</p>
# <p>For Scala, we will do this by plotting a chart of the project's activity. We will calculate the number of pull requests submitted each (calendar) month during the project's lifetime. We will then plot these numbers to see the trend of contributions.</p>
# <ul>
# <li><p>A helpful reminder of how to access various components of a date can be found in <a href="https://campus.datacamp.com/courses/data-manipulation-with-pandas/slicing-and-indexing?ex=12">this exercise of Data Manipulation with pandas</a></p></li>
# <li><p>Additionally, recall that you can group by multiple variables by passing a list to <code>groupby()</code>. This video from <a href="https://campus.datacamp.com/courses/data-manipulation-with-pandas/aggregating-data-ad6d4643-0e95-470c-8299-f69cc4c83de8?ex=9">Data Manipulation with pandas</a> should help!</p></li>
# </ul>

# %%
# %matplotlib inline
def data_to_year(dat):
    return dat.year
def data_to_month(dat):
    return dat.month
# Create a column that will store the month
data['month'] = data['date'].apply(data_to_month)
print(data)
# Create a column that will store the year
data['year'] = data['date'].apply(data_to_year)

print(data)
# Group by the month and year and count the pull requests
counts = data.groupby(['year','month']).agg({'pid':'count'})

# Plot the results
counts.plot(kind='bar', figsize = (12,4))
# Out:
#             pid                user                      date  \
# 0      11166973         VladimirNik 2013-12-31 23:10:55+00:00
# 1      11166973         VladimirNik 2013-12-31 23:10:55+00:00
# 2      11166973         VladimirNik 2013-12-31 23:10:55+00:00
# 3      11166973         VladimirNik 2013-12-31 23:10:55+00:00
# 4      11161892             Ichoran 2013-12-31 16:55:47+00:00
# 5      11153894             Ichoran 2013-12-31 02:41:13+00:00
# 6      11153894             Ichoran 2013-12-31 02:41:13+00:00
# 7      11151917             rklaehn 2013-12-30 23:45:47+00:00
# 8      11151917             rklaehn 2013-12-30 23:45:47+00:00
# 9      11151917             rklaehn 2013-12-30 23:45:47+00:00
# 10     11151917             rklaehn 2013-12-30 23:45:47+00:00
# 11     11131244               qerub 2013-12-29 17:21:01+00:00
# 12     11131244               qerub 2013-12-29 17:21:01+00:00
# 13     11131244               qerub 2013-12-29 17:21:01+00:00
# 14     11131244               qerub 2013-12-29 17:21:01+00:00
# 15     11131244               qerub 2013-12-29 17:21:01+00:00
# 16     11130874             Ichoran 2013-12-29 16:03:55+00:00
#
# 4      src/library/scala/collection/mutable/ArrayOps....     12
# 5      src/library/scala/collection/immutable/Numeric...     12
# 6      test/junit/scala/collection/NumericRangeTest.s...     12
# 7      src/library/scala/collection/immutable/HashMap...     12
# 8      src/library/scala/collection/immutable/HashSet...     12
# 9                             test/files/run/t6196.scala     12
# 10                            test/files/run/t6200.scala     12
# 11                   src/library/scala/Enumeration.scala     12
# 12     src/library/scala/collection/immutable/StringL...     12
# 13           src/library/scala/util/matching/Regex.scala     12
# 14     src/repl/scala/tools/nsc/interpreter/JavapClas...     12
# 15     src/repl/scala/tools/nsc/interpreter/Naming.scala     12
# 16               src/library/scala/math/BigDecimal.scala     12
# 17                   src/library/scala/math/BigInt.scala     12
# 18                          test/files/jvm/bigints.scala     12
# 19                   test/files/run/bigDecimalTest.check     12
# 20                     test/files/run/is-valid-num.scala     12
# 21                         test/files/run/numbereq.scala     12
# 22            test/junit/scala/math/BigDecimalTest.scala     12
# 23     src/library/scala/collection/immutable/HashSet...     12
# 24                            test/files/run/t7326.scala     12
# 25      src/reflect/scala/reflect/internal/Mirrors.scala     12
# 26     test/junit/scala/reflect/internal/MirrorsTest....     12
# 27     src/library/scala/collection/convert/DecorateA...     12
# 28     src/library/scala/collection/convert/WrapAsJav...     12
# 29             src/library/scala/ref/WeakReference.scala     12
# ...                                                  ...    ...
# 85558                         test/files/pos/t8062.flags      1
# 85559                     test/files/pos/t8062/A_1.scala      1
# 85560                     test/files/pos/t8062/B_2.scala      1
# 85561                         test/files/pos/t8111.scala      1
# 85562                test/files/presentation/t8085.check      1
# 85563                test/files/presentation/t8085.flags      1
# 85564           test/files/presentation/t8085/Test.scala      1
# 85565  test/files/presentation/t8085/src/nodescala/Fo...      1
# 85566  test/files/presentation/t8085/src/nodescala/No...      1
# 85567  test/files/presentation/t8085/src/nodescala/pa...      1
# 85568               test/files/presentation/t8085b.check      1
# 85569               test/files/presentation/t8085b.flags      1
# 85570          test/files/presentation/t8085b/Test.scala      1
# 85571  test/files/presentation/t8085b/src/p1/nodescal...      1
# 85572  test/files/presentation/t8085b/src/p1/nodescal...      1
# 85573  test/files/presentation/t8085b/src/p1/nodescal...      1
# 85574                    test/files/run/large_code.check      1
# 85575                    test/files/run/large_code.scala      1
# 85576  src/reflect/scala/reflect/api/StandardLiftable...      1
# 85577  test/files/scalacheck/quasiquotes/LiftableCase...      1
# 85578       test/files/scalacheck/quasiquotes/Test.scala      1
# 85579               src/library/scala/math/Numeric.scala      1
# 85580            test/junit/scala/math/NumericTest.scala      1
# 85581          src/reflect/scala/reflect/api/Trees.scala      1
# 85582  src/library/scala/collection/immutable/HashMap...      1
# 85583  src/library/scala/collection/immutable/HashSet...      1
# 85584  src/library/scala/collection/immutable/HashSet...      1
# 85585                        test/files/run/t6253a.scala      1
# 85586                        test/files/run/t6253b.scala      1
# 85587                        test/files/run/t6253c.scala      1
#
# [85588 rows x 5 columns]
#             pid                user                      date  \
# 0      11166973         VladimirNik 2013-12-31 23:10:55+00:00
# 1      11166973         VladimirNik 2013-12-31 23:10:55+00:00
#
# 85584  11188295             rklaehn 2014-01-02 18:55:33+00:00
# 85585  11188295             rklaehn 2014-01-02 18:55:33+00:00
# 85586  11188295             rklaehn 2014-01-02 18:55:33+00:00
# 85587  11188295             rklaehn 2014-01-02 18:55:33+00:00
#
#                                                     file  month  year
# 0           src/reflect/scala/reflect/api/Printers.scala     12  2013
# 1      src/reflect/scala/reflect/internal/Printers.scala     12  2013
# 2                        test/files/run/reify_ann3.check     12  2013
# 3      test/junit/scala/reflect/internal/PrintersTest...     12  2013
# 4      src/library/scala/collection/mutable/ArrayOps....     12  2013
# 5      src/library/scala/collection/immutable/Numeric...     12  2013
# 6      test/junit/scala/collection/NumericRangeTest.s...     12  2013
# 7      src/library/scala/collection/immutable/HashMap...     12  2013
# 8      src/library/scala/collection/immutable/HashSet...     12  2013
# 9                             test/files/run/t6196.scala     12  2013
# 10                            test/files/run/t6200.scala     12  2013
# 11                   src/library/scala/Enumeration.scala     12  2013
# 12     src/library/scala/collection/immutable/StringL...     12  2013
# 13           src/library/scala/util/matching/Regex.scala     12  2013
# 14     src/repl/scala/tools/nsc/interpreter/JavapClas...     12  2013
# 15     src/repl/scala/tools/nsc/interpreter/Naming.scala     12  2013
# 16               src/library/scala/math/BigDecimal.scala     12  2013
# 17                   src/library/scala/math/BigInt.scala     12  2013
# 18                          test/files/jvm/bigints.scala     12  2013
# 19                   test/files/run/bigDecimalTest.check     12  2013
# 20                     test/files/run/is-valid-num.scala     12  2013
# 21                         test/files/run/numbereq.scala     12  2013
# 22            test/junit/scala/math/BigDecimalTest.scala     12  2013
# 23     src/library/scala/collection/immutable/HashSet...     12  2013
# 24                            test/files/run/t7326.scala     12  2013
# 25      src/reflect/scala/reflect/internal/Mirrors.scala     12  2013
# 26     test/junit/scala/reflect/internal/MirrorsTest....     12  2013
# 27     src/library/scala/collection/convert/DecorateA...     12  2013
# 28     src/library/scala/collection/convert/WrapAsJav...     12  2013
# 29             src/library/scala/ref/WeakReference.scala     12  2013
# ...                                                  ...    ...   ...
# 85558                         test/files/pos/t8062.flags      1  2014
# 85559                     test/files/pos/t8062/A_1.scala      1  2014
# 85560                     test/files/pos/t8062/B_2.scala      1  2014
# 85561                         test/files/pos/t8111.scala      1  2014
# 85562                test/files/presentation/t8085.check      1  2014
# 85563                test/files/presentation/t8085.flags      1  2014
# 85564           test/files/presentation/t8085/Test.scala      1  2014
# 85565  test/files/presentation/t8085/src/nodescala/Fo...      1  2014
# 85566  test/files/presentation/t8085/src/nodescala/No...      1  2014
# 85567  test/files/presentation/t8085/src/nodescala/pa...      1  2014
# 85568               test/files/presentation/t8085b.check      1  2014
# 85569               test/files/presentation/t8085b.flags      1  2014
# 85570          test/files/presentation/t8085b/Test.scala      1  2014
# 85571  test/files/presentation/t8085b/src/p1/nodescal...      1  2014
# 85572  test/files/presentation/t8085b/src/p1/nodescal...      1  2014
# 85573  test/files/presentation/t8085b/src/p1/nodescal...      1  2014
# 85574                    test/files/run/large_code.check      1  2014
# 85575                    test/files/run/large_code.scala      1  2014
# 85576  src/reflect/scala/reflect/api/StandardLiftable...      1  2014
# 85577  test/files/scalacheck/quasiquotes/LiftableCase...      1  2014
# 85578       test/files/scalacheck/quasiquotes/Test.scala      1  2014
# 85579               src/library/scala/math/Numeric.scala      1  2014
# 85580            test/junit/scala/math/NumericTest.scala      1  2014
# 85581          src/reflect/scala/reflect/api/Trees.scala      1  2014
# 85582  src/library/scala/collection/immutable/HashMap...      1  2014
# 85583  src/library/scala/collection/immutable/HashSet...      1  2014
# 85584  src/library/scala/collection/immutable/HashSet...      1  2014
# 85585                        test/files/run/t6253a.scala      1  2014
# 85586                        test/files/run/t6253b.scala      1  2014
# 85587                        test/files/run/t6253c.scala      1  2014
#
# [85588 rows x 6 columns]

# %% [markdown]
# ## 5. Is there camaraderie in the project?
# <p>The organizational structure varies from one project to another, and it can influence your success as a contributor. A project that has a very small community might not be the best one to start working on. The small community might indicate a high barrier of entry. This can be caused by several factors, including a community that is reluctant to accept pull requests from "outsiders," that the code base is hard to work with, etc. However, a large community can serve as an indicator that the project is regularly accepting pull requests from new contributors. Such a project would be a good place to start.</p>
# <p>In order to evaluate the dynamics of the community, we will plot a histogram of the number of pull requests submitted by each user. A distribution that shows that there are few people that only contribute a small number of pull requests can be used as in indicator that the project is not welcoming of new contributors. </p>

# %%
# Required for matplotlib
# %matplotlib inline

# Group by the submitter
by_user =data.groupby('user')['pid'].count()

# Plot the histogram
by_user.plot.hist()

# %% [markdown]
# ## 6. What files were changed in the last ten pull requests?
# <p>Choosing the right place to make a contribution is as important as choosing the project to contribute to. Some parts of the code might be stable, some might be dead. Contributing there might not have the most impact. Therefore it is important to understand the parts of the system that have been recently changed. This allows us to pinpoint the "hot" areas of the code where most of the activity is happening. Focusing on those parts might not the most effective use of our times.</p>

# %%
# Identify the last 10 pull requests
last_10 = pulls.nlargest(10,'date')
print(last_10)
# Join the two data sets
joined_pr = last_10.merge(pull_files,on="pid")
print(joined_pr)
# Identify the unique files
files = joined_pr['file'].unique()

# Print the results
print(files)
# Out:
#          pid         user                      date
# 0  163314316       hrhino 2018-01-16 23:29:16+00:00
# 1  163061502     joroKr21 2018-01-15 23:44:52+00:00
# 2  163057333    mkeskells 2018-01-15 23:05:06+00:00
# 3  162985594        lrytz 2018-01-15 15:52:39+00:00
# 4  162838837    zuvizudar 2018-01-14 19:16:16+00:00
# 5  162765232  howtonotwin 2018-01-13 04:37:17+00:00
# 6  162643301       hrhino 2018-01-12 14:29:49+00:00
# 7  162256029    mkeskells 2018-01-10 23:20:03+00:00
# 8  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 9  162011899     joroKr21 2018-01-10 00:45:57+00:00
#           pid         user                      date  \
# 0   163314316       hrhino 2018-01-16 23:29:16+00:00
# 1   163314316       hrhino 2018-01-16 23:29:16+00:00
# 2   163314316       hrhino 2018-01-16 23:29:16+00:00
# 3   163314316       hrhino 2018-01-16 23:29:16+00:00
# 4   163314316       hrhino 2018-01-16 23:29:16+00:00
# 5   163314316       hrhino 2018-01-16 23:29:16+00:00
# 6   163314316       hrhino 2018-01-16 23:29:16+00:00
# 7   163061502     joroKr21 2018-01-15 23:44:52+00:00
# 8   163057333    mkeskells 2018-01-15 23:05:06+00:00
# 9   163057333    mkeskells 2018-01-15 23:05:06+00:00
# 10  162985594        lrytz 2018-01-15 15:52:39+00:00
# 11  162985594        lrytz 2018-01-15 15:52:39+00:00
# 12  162985594        lrytz 2018-01-15 15:52:39+00:00
# 13  162838837    zuvizudar 2018-01-14 19:16:16+00:00
# 14  162765232  howtonotwin 2018-01-13 04:37:17+00:00
# 15  162765232  howtonotwin 2018-01-13 04:37:17+00:00
# 16  162765232  howtonotwin 2018-01-13 04:37:17+00:00
# 17  162765232  howtonotwin 2018-01-13 04:37:17+00:00
# 18  162765232  howtonotwin 2018-01-13 04:37:17+00:00
# 19  162643301       hrhino 2018-01-12 14:29:49+00:00
# 20  162643301       hrhino 2018-01-12 14:29:49+00:00
# 21  162643301       hrhino 2018-01-12 14:29:49+00:00
# 22  162643301       hrhino 2018-01-12 14:29:49+00:00
# 23  162256029    mkeskells 2018-01-10 23:20:03+00:00
# 24  162256029    mkeskells 2018-01-10 23:20:03+00:00
# 25  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 26  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 27  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 28  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 29  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 30  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 31  162197834    SethTisue 2018-01-10 18:31:25+00:00
# 32  162011899     joroKr21 2018-01-10 00:45:57+00:00
# 33  162011899     joroKr21 2018-01-10 00:45:57+00:00
#
#                                                  file
# 0                     test/files/pos/t5638/Among.java
# 1                    test/files/pos/t5638/Usage.scala
# 2                          test/files/pos/t9291.scala
# 3                          test/files/run/t8348.check
# 4               test/files/run/t8348/TableColumn.java
# 5           test/files/run/t8348/TableColumnImpl.java
# 6                     test/files/run/t8348/Test.scala
# 7             src/library/scala/concurrent/Lock.scala
# 8   src/compiler/scala/tools/nsc/profile/AsyncHelp...
# 9   src/compiler/scala/tools/nsc/profile/Profiler....
# 10  src/compiler/scala/tools/nsc/backend/jvm/BCode...
# 11  src/compiler/scala/tools/nsc/symtab/classfile/...
# 12  src/reflect/scala/reflect/internal/pickling/By...
# 13  src/compiler/scala/reflect/reify/phases/Calcul...
# 14                     src/library/scala/Predef.scala
# 15                test/files/neg/leibniz-liskov.check
# 16                test/files/neg/leibniz-liskov.scala
# 17                test/files/pos/leibniz-liskov.scala
# 18                test/files/pos/leibniz_liskov.scala
# 19  src/compiler/scala/tools/nsc/typechecker/Conte...
# 20          test/files/pos/parallel-classloader.scala
# 21               test/files/pos/t10568/Converter.java
# 22                   test/files/pos/t10568/Impl.scala
# 23  src/compiler/scala/tools/nsc/backend/jvm/PostP...
# 24  src/compiler/scala/tools/nsc/backend/jvm/analy...
# 25                                            LICENSE
# 26                                     doc/LICENSE.md
# 27                                    doc/License.rtf
# 28                          project/VersionUtil.scala
# 29            src/library/scala/util/Properties.scala
# 30  src/scaladoc/scala/tools/nsc/doc/html/page/Ent...
# 31                      src/scalap/decoder.properties
# 32  src/reflect/scala/reflect/internal/tpe/GlbLubs...
# 33                        test/files/pos/t10686.scala
# ['test/files/pos/t5638/Among.java' 'test/files/pos/t5638/Usage.scala'
#  'test/files/pos/t9291.scala' 'test/files/run/t8348.check'
#  'test/files/run/t8348/TableColumn.java'
#  'test/files/run/t8348/TableColumnImpl.java'
#  'test/files/run/t8348/Test.scala'
#  'src/library/scala/concurrent/Lock.scala'
#  'src/compiler/scala/tools/nsc/profile/AsyncHelper.scala'
#  'src/compiler/scala/tools/nsc/profile/Profiler.scala'
#  'src/compiler/scala/tools/nsc/backend/jvm/BCodeHelpers.scala'
#  'src/compiler/scala/tools/nsc/symtab/classfile/ClassfileParser.scala'
#  'src/reflect/scala/reflect/internal/pickling/ByteCodecs.scala'
#  'src/compiler/scala/reflect/reify/phases/Calculate.scala'
#  'src/library/scala/Predef.scala' 'test/files/neg/leibniz-liskov.check'
#  'test/files/neg/leibniz-liskov.scala'
#  'test/files/pos/leibniz-liskov.scala'
#  'test/files/pos/leibniz_liskov.scala'
#  'src/compiler/scala/tools/nsc/typechecker/Contexts.scala'
#  'test/files/pos/parallel-classloader.scala'
#  'test/files/pos/t10568/Converter.java' 'test/files/pos/t10568/Impl.scala'
#  'src/compiler/scala/tools/nsc/backend/jvm/PostProcessor.scala'
#  'src/compiler/scala/tools/nsc/backend/jvm/analysis/BackendUtils.scala'
#  'LICENSE' 'doc/LICENSE.md' 'doc/License.rtf' 'project/VersionUtil.scala'
#  'src/library/scala/util/Properties.scala'
#  'src/scaladoc/scala/tools/nsc/doc/html/page/Entity.scala'
#  'src/scalap/decoder.properties'
#  'src/reflect/scala/reflect/internal/tpe/GlbLubs.scala'
#  'test/files/pos/t10686.scala']

# %% [markdown]
# ## 7. Who made the most pull requests to a given file?
# <p>When contributing to a project, we might need some guidance. We might find ourselves needing some information regarding the codebase. It is important direct any questions to the right person. Contributors to open source projects generally have other day jobs, so their time is limited. It is important to address our questions to the right people. One way to identify the right target for our inquiries is by using their contribution history.</p>
# <p>We identified <code>src/compiler/scala/reflect/reify/phases/Calculate.scala</code> as being recently changed. We are interested in the top 3 developers who changed that file. Those developers are the ones most likely to have the best understanding of the code.</p>

# %%
# This is the file we are interested in:
file = 'src/compiler/scala/reflect/reify/phases/Calculate.scala'

# Identify the commits that changed the file
file_pr = data[data['file'] == file]
#print(file_pr)
# Count the number of changes made by each developer
author_counts = file_pr['user'].value_counts()
print(author_counts.iloc[:3,])
# Print the top 3 developers
# ... YOUR CODE FOR TASK 7 ...
# Out:
# xeno-by     11
# retronym     5
# soc          4
# Name: user, dtype: int64

# %% [markdown]
# ## 8. Who made the last ten pull requests on a given file?
# <p>Open source projects suffer from fluctuating membership. This makes the problem of finding the right person more challenging: the person has to be knowledgeable <em>and</em> still be involved in the project. A person that contributed a lot in the past might no longer be available (or willing) to help. To get a better understanding, we need to investigate the more recent history of that particular part of the system. </p>
# <p>Like in the previous task, we will look at the history of  <code>src/compiler/scala/reflect/reify/phases/Calculate.scala</code>.</p>

# %%
file = 'src/compiler/scala/reflect/reify/phases/Calculate.scala'

# Select the pull requests that changed the target file
file_pr = data[data['file']== file]
#print(file_pr)
# Merge the obtained results with the pulls DataFrame
joined_pr = file_pr.merge(pulls,on="pid")
#print(joined_pr)
# Find the users of the last 10 most recent pull requests
users_last_10 = set(joined_pr.nlargest(10,'date_x')['user_x'])

# Printing the results
print(users_last_10)
# Out:
# {'bjornregnell', 'starblood', 'zuvizudar', 'soc', 'retronym', 'xeno-by'}

# %% [markdown]
# ## 9. The pull requests of two special developers
# <p>Now that we have identified two potential contacts in the projects, we need to find the person who was most involved in the project in recent times. That person is most likely to answer our questions. For each calendar year, we are interested in understanding the number of pull requests the authors submitted. This will give us a high-level image of their contribution trend to the project.</p>

# %%
# %matplotlib inline

# The developers we are interested in
authors = ['xeno-by', 'soc']

# Get all the developers' pull requests
by_author = pulls[pulls['user'].isin(authors)]
#print(by_author)
# Count the number of pull requests submitted each year
counts = by_author.groupby(['user',by_author['date'].dt.year]).agg({'pid': 'count'}).reset_index()
print(counts)
# Convert the table to a wide format
counts_wide = counts.pivot_table(index='user', columns='date', values='pid', fill_value=0)

# Plot the results
print(counts_wide)
# Out:
#        user  date  pid
# 0       soc  2011   12
# 1       soc  2012   44
# 2       soc  2013  117
# 3       soc  2014   20
# 4       soc  2015   24
# 5       soc  2016   21
# 6   xeno-by  2011   20
# 7   xeno-by  2012  271
# 8   xeno-by  2013  123
# 9   xeno-by  2014   60
# 10  xeno-by  2015    3
# date     2011  2012  2013  2014  2015  2016
# user
# soc        12    44   117    20    24    21
# xeno-by    20   271   123    60     3     0

# %% [markdown]
# ## 10. Visualizing the contributions of each developer
# <p>As mentioned before, it is important to make a distinction between the global expertise and contribution levels and the contribution levels at a more granular level (file, submodule, etc.) In our case, we want to see which of our two developers of interest have the most experience with the code in a given file. We will measure experience by the number of pull requests submitted that affect that file and how recent those pull requests were submitted.</p>

# %%
authors = ['xeno-by', 'soc']
file = 'src/compiler/scala/reflect/reify/phases/Calculate.scala'

# Select the pull requests submitted by the authors, from the `data` DataFrame
by_author = data[data['user'].isin(authors)]

# Select the pull requests that affect the file
by_file = by_author[by_author['file']==file]

# Group and count the number of PRs done by each user each year
grouped = by_file.groupby(['user', by_file['date'].dt.year]).count()['pid'].reset_index()
print(grouped)
# Transform the data into a wide format
by_file_wide =grouped.pivot_table(index="user",columns="date",values="pid")

# Plot the results
by_file_wide.plot(kind='bar')
# Out:
#       user  date  pid
# 0      soc  2012    2
# 1      soc  2013    2
# 2  xeno-by  2012   10
# 3  xeno-by  2014    1
